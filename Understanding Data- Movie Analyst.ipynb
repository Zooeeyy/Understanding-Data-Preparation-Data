# %% [markdown]
# ## 💢 Import Library and Data
#
# use vscode

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Use the API to download the dataset. Here is the code to download the dataset from kaggle using API.

# %%
# import kagglehub

# # Download latest version
# path = kagglehub.dataset_download("fatmanur12/movies_metadata")

# print("Path to dataset files:", path)

# %% [markdown]
# ## 💢 Display Data

# %%
dataset = pd.read_csv("C:/Learn n Grow/MySkill/movies_metadata.csv")
dataset.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0   True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   True                                                NaN  65000000
# 2   True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   True                                                NaN  16000000
# 4   True  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
# ...

# %%
dataset.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0   True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   True                                                NaN  65000000
# 2   True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   True                                                NaN  16000000
# 4   True  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# ## 💢 Indexing Data Frames

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=45463, step=1)

# %%
# you can chose whatever you want to be the variable index of the columns

data_movie = dataset.set_index("original_title")
data_movie.head()
# Out:
#                              adult  \
# original_title
# Toy Story                     True
# Jumanji                       True
# Grumpier Old Men              True
# Waiting to Exhale             True
# Father of the Bride Part II   True
#
#                                                          belongs_to_collection  \
# original_title
# Toy Story                    {'id': 10194, 'name': 'Toy Story Collection', ...
# Jumanji                                                                    NaN
# Grumpier Old Men             {'id': 119050, 'name': 'Grumpy Old Men Collect...
# Waiting to Exhale                                                          NaN
# Father of the Bride Part II  {'id': 96871, 'name': 'Father of the Bride Col...
#
#                                budget  \
# original_title
# Toy Story                    30000000
# Jumanji                      65000000
# Grumpier Old Men                    0
# Waiting to Exhale            16000000
# ...

# %%
# if you wanna reset the index before 

data_movie = data_movie.reset_index()

# %%
# show data detail from each data

data_movie.loc[0]
# Out:
# original_title                                                   Toy Story
# adult                                                                 True
# belongs_to_collection    {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                            30000000
# genres                   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                              http://toystory.disney.com/toy-story
# id                                                                     862
# imdb_id                                                          tt0114709
# original_language                                                       en
# overview                 Led by Woody, Andy's toys live happily in his ...
# popularity                                                       21.946943
# poster_path                               /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# ...

# %%
# show data in the dataframe by coloumns and list
data_movie.loc[0,"original_title"]
# Out:
# 'Toy Story'

# %%
data_movie.loc[:, ["original_title", "vote_count"]]
# Out:
#                     original_title  vote_count
# 0                        Toy Story      5415.0
# 1                          Jumanji      2413.0
# 2                 Grumpier Old Men        92.0
# 3                Waiting to Exhale        34.0
# 4      Father of the Bride Part II       173.0
# ...                            ...         ...
# 45458                      رگ خواب         1.0
# 45459          Siglo ng Pagluluwal         3.0
# 45460                     Betrayal         6.0
# 45461          Satana likuyushchiy         0.0
# 45462                     Queerama         0.0
#
# [45463 rows x 2 columns]

# %% [markdown]
# ## 💢 Data Columns

# %%
# show the first data until 10 

dataset.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0   True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   True                                                NaN  65000000
# 2   True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   True                                                NaN  16000000
# 4   True  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   True                                                NaN  60000000
# 6   True                                                NaN  58000000
# 7   True                                                NaN         0
# 8   True                                                NaN  35000000
# 9   True  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
# show end of dataset

dataset.tail()
# Out:
#        adult belongs_to_collection  budget  \
# 45458   True                   NaN       0
# 45459   True                   NaN       0
# 45460   True                   NaN       0
# 45461   True                   NaN       0
# 45462   True                   NaN       0
#
#                                                   genres  \
# 45458  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45459                      [{'id': 18, 'name': 'Drama'}]
# 45460  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45461                                                 []
# 45462                                                 []
#
#                                    homepage      id    imdb_id  \
# 45458  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45459                                   NaN  111109  tt2028550
# 45460                                   NaN   67758  tt0303758
# 45461                                   NaN  227506  tt0008536
# ...

# %%
dataset.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
data_movie.columns
# Out:
# Index(['original_title', 'adult', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'id', 'imdb_id', 'original_language', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# ## 💢 Data Type Convertion

# %%
data_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   original_title         45463 non-null  object
#  1   adult                  45463 non-null  bool
#  2   belongs_to_collection  4491 non-null   object
#  3   budget                 45463 non-null  int64
#  4   genres                 45463 non-null  object
#  5   homepage               7779 non-null   object
#  6   id                     45463 non-null  int64
#  7   imdb_id                45446 non-null  object
#  8   original_language      45452 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
# ...

# %%
# change data type release_date from object to datetime

data_movie ["release_date"] = pd.to_datetime(data_movie["release_date"])

# %%
data_movie["release_date"]
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 45458          NaT
# 45459   2011-11-17
# 45460   2003-08-01
# 45461   1917-10-21
# 45462   2017-06-09
# Name: release_date, Length: 45463, dtype: datetime64[ns]

# %%
# showed unique values in the column status
data_movie["status"].unique()
# Out:
# array(['Released', nan, 'Rumored', 'Post Production', 'In Production',
#        'Planned', 'Canceled'], dtype=object)

# %%
data_movie["original_language"].unique()
# Out:
# array(['en', 'fr', 'zh', 'it', 'fa', 'nl', 'de', 'cn', 'ar', 'es', 'ru',
#        'sv', 'ja', 'ko', 'sr', 'bn', 'he', 'pt', 'wo', 'ro', 'hu', 'cy',
#        'vi', 'cs', 'da', 'no', 'nb', 'pl', 'el', 'sh', 'xx', 'mk', 'bo',
#        'ca', 'fi', 'th', 'sk', 'bs', 'hi', 'tr', 'is', 'ps', 'ab', 'eo',
#        'ka', 'mn', 'bm', 'zu', 'uk', 'af', 'la', 'et', 'ku', 'fy', 'lv',
#        'ta', 'sl', 'tl', 'ur', 'rw', 'id', 'bg', 'mr', 'lt', 'kk', 'ms',
#        'sq', nan, 'qu', 'te', 'am', 'jv', 'tg', 'ml', 'hr', 'lo', 'ay',
#        'kn', 'eu', 'ne', 'pa', 'ky', 'gl', 'uz', 'sm', 'mt', 'hy', 'iu',
#        'lb', 'si'], dtype=object)

# %%
#count a uniq value in a coloumn list
data_movie["original_language"].nunique()
# Out:
# 89

# %% [markdown]
# ## 💢 Filter Data

# %%
# check the movie who has a status of 'released'
data_movie["status"] == "Released"
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 45458    True
# 45459    True
# 45460    True
# 45461    True
# 45462    True
# Name: status, Length: 45463, dtype: bool

# %%
# filter the movie who has a status of 'released'
data_movie[data_movie["status"] == "Released"]
# Out:
#                     original_title  adult  \
# 0                        Toy Story   True
# 1                          Jumanji   True
# 2                 Grumpier Old Men   True
# 3                Waiting to Exhale   True
# 4      Father of the Bride Part II   True
# ...                            ...    ...
# 45458                      رگ خواب   True
# 45459          Siglo ng Pagluluwal   True
# 45460                     Betrayal   True
# 45461          Satana likuyushchiy   True
# 45462                     Queerama   True
#
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...

# %%
# filter the data who has status 'released' and language 'eng'

english_release = data_movie[(data_movie["status"]=="Released") & \
                             (data_movie["original_language"] =="en")]

english_release.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31952 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   original_title         31952 non-null  object
#  1   adult                  31952 non-null  bool
#  2   belongs_to_collection  3099 non-null   object
#  3   budget                 31952 non-null  int64
#  4   genres                 31952 non-null  object
#  5   homepage               6103 non-null   object
#  6   id                     31952 non-null  int64
#  7   imdb_id                31941 non-null  object
#  8   original_language      31952 non-null  object
#  9   overview               31888 non-null  object
#  10  popularity             31952 non-null  float64
#  11  poster_path            31641 non-null  object
#  12  production_companies   31952 non-null  object
#  13  production_countries   31952 non-null  object
# ...

# %% [markdown]
# ## 💢 Sorting Data

# %%
from numpy import short

# shorting the films who has a budget greater

english_release.sort_values("budget", ascending= False).head(10)
# Out:
#                                     original_title  adult  \
# 17124  Pirates of the Caribbean: On Stranger Tides   True
# 11827     Pirates of the Caribbean: At World's End   True
# 26557                      Avengers: Age of Ultron   True
# 11067                             Superman Returns   True
# 44839                Transformers: The Last Knight   True
# 16130                                      Tangled   True
# 18685                                  John Carter   True
# 11780                                 Spider-Man 3   True
# 21174                              The Lone Ranger   True
# 25389    The Hobbit: The Battle of the Five Armies   True
#
#                                    belongs_to_collection     budget  \
# 17124  {'id': 295, 'name': 'Pirates of the Caribbean ...  380000000
# 11827  {'id': 295, 'name': 'Pirates of the Caribbean ...  300000000
# 26557  {'id': 86311, 'name': 'The Avengers Collection...  280000000
# ...

# %%
# budget dan revenue

english_release.sort_values(["budget","revenue"], ascending= [False,False]).head(10)
# Out:
#                                     original_title  adult  \
# 17124  Pirates of the Caribbean: On Stranger Tides   True
# 11827     Pirates of the Caribbean: At World's End   True
# 26557                      Avengers: Age of Ultron   True
# 11067                             Superman Returns   True
# 44839                Transformers: The Last Knight   True
# 16130                                      Tangled   True
# 18685                                  John Carter   True
# 11780                                 Spider-Man 3   True
# 21174                              The Lone Ranger   True
# 43252                      The Fate of the Furious   True
#
#                                    belongs_to_collection     budget  \
# 17124  {'id': 295, 'name': 'Pirates of the Caribbean ...  380000000
# 11827  {'id': 295, 'name': 'Pirates of the Caribbean ...  300000000
# 26557  {'id': 86311, 'name': 'The Avengers Collection...  280000000
# ...

# %% [markdown]
# ## 💢 Data Duplicate

# %%
# how to check duplicate data in a dataframe

english_release[english_release.duplicated()]
# Out:
#                          original_title  adult  \
# 9327                        The Warrior   True
# 21164                       The Tempest   True
# 21853                      The Congress   True
# 22150                  Days of Darkness   True
# 24843                              Deal   True
# 28859                              Nana   True
# 35795  Why We Fight: Divide and Conquer   True
# 38868                        The Viking   True
# 40273              Seven Years Bad Luck   True
#
#                                    belongs_to_collection  budget  \
# 9327                                                 NaN       0
# 21164                                                NaN       0
# 21853                                                NaN       0
# 22150                                                NaN       0
# 24843                                                NaN       0
# 28859                                                NaN       0
# ...

# %%
# check count of duplicate

english_release.duplicated().sum()
# Out:
# np.int64(9)

# %%
# check count of data duplicate as a title

english_release.duplicated(subset="original_title").sum()
# Out:
# np.int64(1746)

# %%
# showed data who has duplicated title from original_title coloumn

english_release[english_release.duplicated(subset="original_title")]
# Out:
#            original_title  adult belongs_to_collection   budget  \
# 888               Sabrina   True                   NaN  2238813
# 930    The Scarlet Letter   True                   NaN        0
# 1296            Cape Fear   True                   NaN        0
# 1832               Hamlet   True                   NaN   750000
# 1950      The Parent Trap   True                   NaN        0
# ...                   ...    ...                   ...      ...
# 45412         The Hunters   True                   NaN        0
# 45417      Arabian Nights   True                   NaN        0
# 45451   The Morning After   True                   NaN        0
# 45457          Robin Hood   True                   NaN        0
# 45460            Betrayal   True                   NaN        0
#
#                                                   genres homepage      id  \
# 888    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN    6620
# ...

# %%
english_release[english_release.duplicated(subset="original_title", keep=False)].sort_values("original_title")
# Out:
#                      original_title  adult  \
# 15200                  12 Angry Men   True
# 1161                   12 Angry Men   True
# 20847  20,000 Leagues Under the Sea   True
# 13003  20,000 Leagues Under the Sea   True
# 24108  20,000 Leagues Under the Sea   True
# ...                             ...    ...
# 11646                        Zodiac   True
# 37896                          Zoom   True
# 11171                          Zoom   True
# 5761                           Zulu   True
# 24662                          Zulu   True
#
#                                    belongs_to_collection    budget  \
# 15200                                                NaN         0
# 1161                                                 NaN    350000
# 20847                                                NaN         0
# 13003                                                NaN    200000
# 24108                                                NaN         0
# ...

# %%
# drop data duplicated

english_release.drop_duplicates(inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_27980\3725261058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_release.drop_duplicates(inplace=True)

# %%
english_release.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 💢 Missing Values

# %%
# check count of missing values

english_release.isna().sum()
# Out:
# original_title               0
# adult                        0
# belongs_to_collection    28845
# budget                       0
# genres                       0
# homepage                 25842
# id                           0
# imdb_id                     11
# original_language            0
# overview                    64
# popularity                   0
# poster_path                311
# production_companies         0
# production_countries         0
# release_date                59
# revenue                      0
# runtime                      6
# spoken_languages             0
# status                       0
# tagline                  14114
# title                        0
# video                        0
# vote_average                 0
# vote_count                   0
# dtype: int64

# %%
# fill new values for coloumns tagline
english_release["tagline"] = english_release["tagline"].fillna("No tagline")

# fill new values for coloumns collection
english_release["belongs_to_collection"] = english_release["belongs_to_collection"].fillna("No Data")

# fill new values for coloumns homepage
english_release["homepage"] = english_release["homepage"].fillna("No Data")

# fill new values for coloumns poster_path
english_release["poster_path"] = english_release["poster_path"].fillna("No Data")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_27980\711964726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_release["tagline"] = english_release["tagline"].fillna("No tagline")
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_27980\711964726.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_release["belongs_to_collection"] = english_release["belongs_to_collection"].fillna("No Data")
# ...

# %%
# chcek missing values
english_release.dropna(inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_27980\2568499517.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_release.dropna(inplace=True)

# %%
english_release.shape
# Out:
# (31813, 24)

# %%
# sorting film from highest rating to lowest

english_release.sort_values("vote_count", ascending=False).head()
# Out:
#         original_title  adult  \
# 15480        Inception   True
# 12481  The Dark Knight   True
# 14551           Avatar   True
# 17818     The Avengers   True
# 26563         Deadpool   True
#
#                                    belongs_to_collection     budget  \
# 15480                                            No Data  160000000
# 12481  {'id': 263, 'name': 'The Dark Knight Collectio...  185000000
# 14551  {'id': 87096, 'name': 'Avatar Collection', 'po...  237000000
# 17818  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 26563  {'id': 448150, 'name': 'Deadpool Collection', ...   58000000
#
#                                                   genres  \
# 15480  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 12481  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 14551  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 17818  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 26563  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
# ...

# %%
# show film who has runtime more than 3 hours

english_release[english_release["runtime"]> 60*3].head()
# Out:
#          original_title  adult belongs_to_collection    budget  \
# 13                Nixon   True               No Data  44000000
# 378          Wyatt Earp   True               No Data  63000000
# 522    Schindler's List   True               No Data  22000000
# 530          Short Cuts   True               No Data         0
# 583  Dances with Wolves   True               No Data  22000000
#
#                                                 genres  \
# 13   [{'id': 36, 'name': 'History'}, {'id': 18, 'na...
# 378  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 522  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 530  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 583  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
#
#                            homepage     id    imdb_id original_language  \
# 13                          No Data  10858  tt0113987                en
# 378                         No Data  12160  tt0111756                en
# ...
